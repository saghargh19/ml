# %%
import torch
import torchvision
import torchvision.transforms as transforms
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt

# Data Augmentation
transform_train = transforms.Compose([
    transforms.RandomHorizontalFlip(),
    transforms.RandomCrop(32, padding=4),
    transforms.ToTensor(),
])

transform_test = transforms.Compose([
    transforms.ToTensor(),
])

# Load CIFAR10 Dataset
trainset = torchvision.datasets.CIFAR10(root='./data', train=True,
                                        download=True, transform=transform_train)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=128,
                                          shuffle=True, num_workers=2)

testset = torchvision.datasets.CIFAR10(root='./data', train=False,
                                       download=True, transform=transform_test)
testloader = torch.utils.data.DataLoader(testset, batch_size=100,
                                         shuffle=False, num_workers=2)

# Define the Wide ResNet Model
class WideResNet(nn.Module):
    def __init__(self, block, num_blocks, k=2, num_classes=10):
        super(WideResNet, self).__init__()
        self.in_planes = 16
        self.conv1 = nn.Conv2d(3, 16, kernel_size=5, stride=1, padding=2, bias=False)
        self.layer1 = self._make_layer(block, 16*k, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, 32*k, num_blocks[1], stride=2)
        self.layer3 = self._make_layer(block, 64*k, num_blocks[2], stride=2)
        self.bn1 = nn.BatchNorm2d(64*k)
        self.linear = nn.Linear(64*k, num_classes)

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1] * (num_blocks - 1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes * block.expansion
        return nn.Sequential(*layers)

    def forward(self, x):
        out = nn.functional.relu(self.conv1(x))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = nn.functional.avg_pool2d(self.bn1(out), 8)
        out = out.view(out.size(0), -1)
        out = self.linear(out)
        return out

# Define the Residual Block
class BasicBlock(nn.Module):
    expansion = 1

    def __init__(self, in_planes, planes, stride=1):
        super(BasicBlock, self).__init__()
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)
        self.bn2 = nn.BatchNorm2d(planes)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != self.expansion * planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, self.expansion * planes, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(self.expansion * planes)
            )

    def forward(self, x):
        out = nn.functional.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x)
        out = nn.functional.relu(out)
        return out

# Initialize the Wide ResNet Model
def WideResNet28_2():
    return WideResNet(BasicBlock, [4, 4, 4], k=2)

# Training function
def train(net, criterion, optimizer, trainloader):
    net.train()
    train_loss = 0
    correct = 0
    total = 0
    for inputs, labels in trainloader:
        optimizer.zero_grad()
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = net(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        train_loss += loss.item()
        _, predicted = outputs.max(1)
        total += labels.size(0)
        correct += predicted.eq(labels).sum().item()

    return train_loss, 100 * correct / total

# Testing function
def test(net, criterion, testloader):
    net.eval()
    test_loss = 0
    correct = 0
    total = 0
    with torch.no_grad():
        for inputs, labels in testloader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = net(inputs)
            loss = criterion(outputs, labels)

            test_loss += loss.item()
            _, predicted = outputs.max(1)
            total += labels.size(0)
            correct += predicted.eq(labels).sum().item()

    return test_loss, 100 * correct / total

# Set device (GPU if available)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Create WideResNet28-2 model
net = WideResNet28_2()
net = net.to(device)

# Define loss function and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=0.01, momentum=0.9)

# Training settings
num_epochs = 100
train_losses = []
train_accuracies = []
test_losses = []
test_accuracies = []

# Training loop
for epoch in range(num_epochs):
    train_loss, train_accuracy = train(net, criterion, optimizer, trainloader)
    test_loss, test_accuracy = test(net, criterion, testloader)

    train_losses.append(train_loss)
    train_accuracies.append(train_accuracy)
    test_losses.append(test_loss)
    test_accuracies.append(test_accuracy)

    print(f"Epoch {epoch+1}/{num_epochs}:")
    print(f"Train Loss: {train_loss:.3f} | Train Accuracy: {train_accuracy:.2f}%")
    print(f"Test Loss: {test_loss:.3f} | Test Accuracy: {test_accuracy:.2f}%")
    print()

# Plotting the results
plt.figure(figsize=(10, 5))
plt.plot(range(num_epochs), train_accuracies, label='Train')
plt.plot(range(num_epochs), test_accuracies, label='Test')
plt.title('Training and Test Accuracies')
plt.xlabel('Epochs')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.show()
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
# 100%|██████████| 170498071/170498071 [00:02<00:00, 84947659.24it/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified
# Epoch 1/100:
# Train Loss: 583.925 | Train Accuracy: 44.98%
# Test Loss: 132.917 | Test Accuracy: 51.95%
#
# Epoch 2/100:
# Train Loss: 395.472 | Train Accuracy: 63.80%
# Test Loss: 122.748 | Test Accuracy: 59.01%
#
# Epoch 3/100:
# Train Loss: 307.455 | Train Accuracy: 72.49%
# Test Loss: 116.786 | Test Accuracy: 62.34%
#
# Epoch 4/100:
# Train Loss: 261.664 | Train Accuracy: 76.63%
# Test Loss: 79.859 | Test Accuracy: 72.96%
#
# Epoch 5/100:
# Train Loss: 227.534 | Train Accuracy: 79.88%
# Test Loss: 81.686 | Test Accuracy: 72.74%
#
# Epoch 6/100:
# Train Loss: 206.012 | Train Accuracy: 81.71%
# Test Loss: 60.102 | Test Accuracy: 80.07%
#
# Epoch 7/100:
# Train Loss: 188.281 | Train Accuracy: 83.13%
# Test Loss: 55.167 | Test Accuracy: 81.32%
#
# Epoch 8/100:
# Train Loss: 173.427 | Train Accuracy: 84.72%
# Test Loss: 64.285 | Test Accuracy: 79.31%
#
# Epoch 9/100:
# Train Loss: 162.585 | Train Accuracy: 85.57%
# Test Loss: 53.984 | Test Accuracy: 81.89%
#
# Epoch 10/100:
# Train Loss: 151.189 | Train Accuracy: 86.71%
# Test Loss: 49.722 | Test Accuracy: 83.52%
#
# Epoch 11/100:
# Train Loss: 140.913 | Train Accuracy: 87.51%
# Test Loss: 52.270 | Test Accuracy: 82.40%
#
# Epoch 12/100:
# Train Loss: 133.115 | Train Accuracy: 88.31%
# Test Loss: 48.943 | Test Accuracy: 83.31%
#
# Epoch 13/100:
# Train Loss: 125.612 | Train Accuracy: 88.90%
# Test Loss: 49.598 | Test Accuracy: 83.57%
#
# Epoch 14/100:
# Train Loss: 119.145 | Train Accuracy: 89.52%
# Test Loss: 43.784 | Test Accuracy: 85.48%
#
# Epoch 15/100:
# Train Loss: 113.581 | Train Accuracy: 90.01%
# Test Loss: 44.363 | Test Accuracy: 85.48%
#
# Epoch 16/100:
# Train Loss: 108.271 | Train Accuracy: 90.33%
# Test Loss: 49.083 | Test Accuracy: 84.29%
#
# Epoch 17/100:
# Train Loss: 102.049 | Train Accuracy: 90.84%
# Test Loss: 49.041 | Test Accuracy: 84.85%
#
# Epoch 18/100:
# Train Loss: 95.552 | Train Accuracy: 91.59%
# Test Loss: 47.911 | Test Accuracy: 85.25%
#
# Epoch 19/100:
# Train Loss: 92.284 | Train Accuracy: 91.77%
# Test Loss: 52.747 | Test Accuracy: 83.94%
#
# Epoch 20/100:
# Train Loss: 88.386 | Train Accuracy: 92.14%
# Test Loss: 50.810 | Test Accuracy: 84.64%
#
# Epoch 21/100:
# Train Loss: 84.613 | Train Accuracy: 92.39%
# Test Loss: 40.501 | Test Accuracy: 87.05%
#
# Epoch 22/100:
# Train Loss: 79.055 | Train Accuracy: 92.84%
# Test Loss: 42.932 | Test Accuracy: 87.00%
#
# Epoch 23/100:
# Train Loss: 76.128 | Train Accuracy: 93.16%
# Test Loss: 36.065 | Test Accuracy: 88.69%
#
# Epoch 24/100:
# Train Loss: 73.549 | Train Accuracy: 93.36%
# Test Loss: 41.158 | Test Accuracy: 87.19%
#
# Epoch 25/100:
# Train Loss: 70.083 | Train Accuracy: 93.65%
# Test Loss: 41.728 | Test Accuracy: 87.29%
#
# Epoch 26/100:
# Train Loss: 66.779 | Train Accuracy: 93.95%
# Test Loss: 39.997 | Test Accuracy: 88.15%
#
# Epoch 27/100:
# Train Loss: 64.257 | Train Accuracy: 94.23%
# Test Loss: 38.413 | Test Accuracy: 87.98%
#
# Epoch 28/100:
# Train Loss: 60.477 | Train Accuracy: 94.51%
# Test Loss: 38.816 | Test Accuracy: 88.34%
#
# Epoch 29/100:
# Train Loss: 59.325 | Train Accuracy: 94.59%
# Test Loss: 47.255 | Test Accuracy: 87.20%
#
# Epoch 30/100:
# Train Loss: 58.492 | Train Accuracy: 94.64%
# Test Loss: 40.611 | Test Accuracy: 88.25%
#
# Epoch 31/100:
# Train Loss: 53.712 | Train Accuracy: 95.15%
# Test Loss: 42.372 | Test Accuracy: 87.73%
#
# Epoch 32/100:
# Train Loss: 53.249 | Train Accuracy: 95.18%
# Test Loss: 42.846 | Test Accuracy: 87.50%
#
# Epoch 33/100:
# Train Loss: 51.065 | Train Accuracy: 95.43%
# Test Loss: 36.400 | Test Accuracy: 89.22%
#
# Epoch 34/100:
# Train Loss: 46.290 | Train Accuracy: 95.88%
# Test Loss: 39.199 | Test Accuracy: 89.21%
#
# Epoch 35/100:
# Train Loss: 45.995 | Train Accuracy: 95.86%
# Test Loss: 40.855 | Test Accuracy: 89.00%
#
# Epoch 36/100:
# Train Loss: 43.176 | Train Accuracy: 96.03%
# Test Loss: 38.428 | Test Accuracy: 89.63%
#
# Epoch 37/100:
# Train Loss: 42.612 | Train Accuracy: 96.16%
# Test Loss: 43.162 | Test Accuracy: 88.73%
#
# Epoch 38/100:
# Train Loss: 40.774 | Train Accuracy: 96.28%
# Test Loss: 43.962 | Test Accuracy: 88.33%
#
# Epoch 39/100:
# Train Loss: 37.482 | Train Accuracy: 96.61%
# Test Loss: 42.236 | Test Accuracy: 88.67%
#
# Epoch 40/100:
# Train Loss: 39.118 | Train Accuracy: 96.44%
# Test Loss: 40.202 | Test Accuracy: 89.15%
#
# Epoch 41/100:
# Train Loss: 35.959 | Train Accuracy: 96.76%
# Test Loss: 44.416 | Test Accuracy: 88.36%
#
# Epoch 42/100:
# Train Loss: 35.374 | Train Accuracy: 96.80%
# Test Loss: 38.184 | Test Accuracy: 89.92%
#
# Epoch 43/100:
# Train Loss: 33.120 | Train Accuracy: 96.99%
# Test Loss: 48.140 | Test Accuracy: 88.31%
#
# Epoch 44/100:
# Train Loss: 35.240 | Train Accuracy: 96.81%
# Test Loss: 40.388 | Test Accuracy: 89.95%
#
# Epoch 45/100:
# Train Loss: 31.663 | Train Accuracy: 97.13%
# Test Loss: 41.837 | Test Accuracy: 89.43%
#
# Epoch 46/100:
# Train Loss: 29.635 | Train Accuracy: 97.38%
# Test Loss: 43.278 | Test Accuracy: 89.32%
#
# Epoch 47/100:
# Train Loss: 29.994 | Train Accuracy: 97.26%
# Test Loss: 42.176 | Test Accuracy: 89.47%
#
# Epoch 48/100:
# Train Loss: 28.360 | Train Accuracy: 97.42%
# Test Loss: 43.894 | Test Accuracy: 88.89%
#
# Epoch 49/100:
# Train Loss: 27.033 | Train Accuracy: 97.57%
# Test Loss: 41.280 | Test Accuracy: 89.85%
#
# Epoch 50/100:
# Train Loss: 27.337 | Train Accuracy: 97.48%
# Test Loss: 39.989 | Test Accuracy: 89.87%
#
# Epoch 51/100:
# Train Loss: 25.193 | Train Accuracy: 97.73%
# Test Loss: 44.688 | Test Accuracy: 89.50%
#
# Epoch 52/100:
# Train Loss: 26.130 | Train Accuracy: 97.65%
# Test Loss: 41.081 | Test Accuracy: 89.94%
#
# Epoch 53/100:
# Train Loss: 23.295 | Train Accuracy: 97.86%
# Test Loss: 42.204 | Test Accuracy: 90.26%
#
# Epoch 54/100:
# Train Loss: 23.751 | Train Accuracy: 97.84%
# Test Loss: 43.878 | Test Accuracy: 89.39%
#
# Epoch 55/100:
# Train Loss: 23.189 | Train Accuracy: 97.92%
# Test Loss: 40.314 | Test Accuracy: 90.59%
#
# Epoch 56/100:
# Train Loss: 21.528 | Train Accuracy: 98.07%
# Test Loss: 40.690 | Test Accuracy: 90.53%
#
# Epoch 57/100:
# Train Loss: 22.320 | Train Accuracy: 97.94%
# Test Loss: 44.252 | Test Accuracy: 89.92%
#
# Epoch 58/100:
# Train Loss: 19.617 | Train Accuracy: 98.23%
# Test Loss: 43.522 | Test Accuracy: 89.93%
#
# Epoch 59/100:
# Train Loss: 21.361 | Train Accuracy: 97.99%
# Test Loss: 44.174 | Test Accuracy: 90.35%
#
# Epoch 60/100:
# Train Loss: 17.984 | Train Accuracy: 98.38%
# Test Loss: 40.386 | Test Accuracy: 90.80%
#
# Epoch 61/100:
# Train Loss: 19.229 | Train Accuracy: 98.29%
# Test Loss: 43.304 | Test Accuracy: 90.05%
#
# Epoch 62/100:
# Train Loss: 18.485 | Train Accuracy: 98.36%
# Test Loss: 45.789 | Test Accuracy: 90.05%
#
# Epoch 63/100:
# Train Loss: 16.218 | Train Accuracy: 98.51%
# Test Loss: 44.635 | Test Accuracy: 90.52%
#
# Epoch 64/100:
# Train Loss: 17.688 | Train Accuracy: 98.43%
# Test Loss: 45.488 | Test Accuracy: 89.99%
#
# Epoch 65/100:
# Train Loss: 16.856 | Train Accuracy: 98.48%
# Test Loss: 51.134 | Test Accuracy: 89.13%
#
# Epoch 66/100:
# Train Loss: 17.060 | Train Accuracy: 98.44%
# Test Loss: 45.545 | Test Accuracy: 90.52%
#
# Epoch 67/100:
# Train Loss: 16.398 | Train Accuracy: 98.50%
# Test Loss: 44.482 | Test Accuracy: 90.58%
#
# Epoch 68/100:
# Train Loss: 15.084 | Train Accuracy: 98.70%
# Test Loss: 45.669 | Test Accuracy: 90.80%
#
# Epoch 69/100:
# Train Loss: 14.968 | Train Accuracy: 98.64%
# Test Loss: 42.800 | Test Accuracy: 90.80%
#
# Epoch 70/100:
# Train Loss: 13.819 | Train Accuracy: 98.79%
# Test Loss: 44.798 | Test Accuracy: 90.67%
#
# Epoch 71/100:
# Train Loss: 14.690 | Train Accuracy: 98.73%
# Test Loss: 45.271 | Test Accuracy: 90.66%
#
# Epoch 72/100:
# Train Loss: 14.861 | Train Accuracy: 98.61%
# Test Loss: 44.121 | Test Accuracy: 90.83%
#
# Epoch 73/100:
# Train Loss: 14.013 | Train Accuracy: 98.75%
# Test Loss: 47.177 | Test Accuracy: 90.22%
#
# Epoch 74/100:
# Train Loss: 13.760 | Train Accuracy: 98.77%
# Test Loss: 43.761 | Test Accuracy: 91.00%
#
# Epoch 75/100:
# Train Loss: 14.639 | Train Accuracy: 98.69%
# Test Loss: 53.935 | Test Accuracy: 88.99%
#
# Epoch 76/100:
# Train Loss: 12.760 | Train Accuracy: 98.86%
# Test Loss: 42.235 | Test Accuracy: 90.91%
#
# Epoch 77/100:
# Train Loss: 12.854 | Train Accuracy: 98.88%
# Test Loss: 42.823 | Test Accuracy: 91.35%
#
# Epoch 78/100:
# Train Loss: 11.874 | Train Accuracy: 98.97%
# Test Loss: 45.082 | Test Accuracy: 90.88%
#
# Epoch 79/100:
# Train Loss: 11.419 | Train Accuracy: 99.00%
# Test Loss: 43.239 | Test Accuracy: 91.15%
#
# Epoch 80/100:
# Train Loss: 10.418 | Train Accuracy: 99.08%
# Test Loss: 45.387 | Test Accuracy: 91.05%
#
# Epoch 81/100:
# Train Loss: 10.686 | Train Accuracy: 99.06%
# Test Loss: 48.303 | Test Accuracy: 90.27%
#
# Epoch 82/100:
# Train Loss: 12.366 | Train Accuracy: 98.93%
# Test Loss: 48.858 | Test Accuracy: 90.12%
#
# Epoch 83/100:
# Train Loss: 9.986 | Train Accuracy: 99.16%
# Test Loss: 46.104 | Test Accuracy: 91.28%
#
# Epoch 84/100:
# Train Loss: 9.746 | Train Accuracy: 99.16%
# Test Loss: 44.882 | Test Accuracy: 91.43%
#
# Epoch 85/100:
# Train Loss: 10.615 | Train Accuracy: 99.05%
# Test Loss: 46.564 | Test Accuracy: 91.05%
#
# Epoch 86/100:
# Train Loss: 9.134 | Train Accuracy: 99.18%
# Test Loss: 42.603 | Test Accuracy: 91.56%
#
# Epoch 87/100:
# Train Loss: 8.510 | Train Accuracy: 99.29%
# Test Loss: 45.890 | Test Accuracy: 91.11%
#
# Epoch 88/100:
# Train Loss: 10.801 | Train Accuracy: 99.05%
# Test Loss: 47.395 | Test Accuracy: 90.68%
#
# Epoch 89/100:
# Train Loss: 9.945 | Train Accuracy: 99.16%
# Test Loss: 49.429 | Test Accuracy: 90.37%
#
# Epoch 90/100:
# Train Loss: 10.064 | Train Accuracy: 99.05%
# Test Loss: 49.100 | Test Accuracy: 90.51%
#
# Epoch 91/100:
# Train Loss: 9.882 | Train Accuracy: 99.13%
# Test Loss: 46.830 | Test Accuracy: 90.94%
#
# Epoch 92/100:
# Train Loss: 9.786 | Train Accuracy: 99.14%
# Test Loss: 46.151 | Test Accuracy: 90.88%
#
# Epoch 93/100:
# Train Loss: 8.571 | Train Accuracy: 99.24%
# Test Loss: 49.142 | Test Accuracy: 90.73%
#
# Epoch 94/100:
# Train Loss: 9.599 | Train Accuracy: 99.12%
# Test Loss: 49.086 | Test Accuracy: 90.73%
#
# Epoch 95/100:
# Train Loss: 9.054 | Train Accuracy: 99.18%
# Test Loss: 46.005 | Test Accuracy: 90.68%
#
# Epoch 96/100:
# Train Loss: 8.324 | Train Accuracy: 99.28%
# Test Loss: 46.680 | Test Accuracy: 90.88%
#
# Epoch 97/100:
# Train Loss: 7.993 | Train Accuracy: 99.29%
# Test Loss: 46.439 | Test Accuracy: 91.11%
#
# Epoch 98/100:
# Train Loss: 8.556 | Train Accuracy: 99.24%
# Test Loss: 52.887 | Test Accuracy: 90.31%
#
# Epoch 99/100:
# Train Loss: 8.365 | Train Accuracy: 99.26%
# Test Loss: 46.744 | Test Accuracy: 91.35%
#
# Epoch 100/100:
# Train Loss: 8.340 | Train Accuracy: 99.25%
# Test Loss: 48.874 | Test Accuracy: 90.87%
